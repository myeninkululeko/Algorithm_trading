# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
#getting the data for capitec for the past 6 months
data=yf.download("CPI.JO",start="2020-03-15",end="2020-07-21",interval="5d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                 Open           High           Low          Close  \
# Date
# 2020-03-19   80000.0   81000.000000   53986.00000   68250.000000
# 2020-03-24   93001.0   97000.000000   88798.00000   95800.000000
# 2020-04-03   92500.0   92982.000000   87501.00000   91599.000000
# 2020-04-08  108500.0  108483.000000  100000.00000  102470.000000
# 2020-04-23   94311.0   95577.000000   86000.00000   92417.000000
# 2020-04-28   92800.0   95496.000000   88150.00000   88150.000000
# 2020-05-08   88000.0   89859.000000   85903.00000   87853.000000
# 2020-05-13   84500.0   83982.000000   80600.00000   82993.000000
# 2020-05-18   81500.0   83484.000000   79672.00000   83484.000000
# 2020-05-28   87500.0   93500.000000   86501.00000   89028.000000
# 2020-06-02   87123.0   90446.000000   85207.00000   90383.000000
# 2020-06-12   88799.0   91831.000000   87163.00000   91780.000000
# 2020-06-17   91090.0   92869.000000   90360.00000   91200.000000
# ...

# %%
from yahoofinancials import YahooFinancials

# %%
ticker="CPI.JO"
yahoo_financials = YahooFinancials(ticker)

# %%
data2=yahoo_financials.get_historical_price_data("2020-03-16","2020-07-22","daily")

# %%
# Out:
# {'CPI.JO': {'eventsData': {},
#   'firstTradeDate': {'formatted_date': '2002-02-19', 'date': 1014102000},
#   'currency': 'ZAc',
#   'instrumentType': 'EQUITY',
#   'timeZone': {'gmtOffset': 7200},
#   'prices': [{'date': 1584342000,
#     'high': 116001.0,
#     'low': 105000.0,
#     'open': 117900.0,
#     'close': 112197.0,
#     'volume': 496227,
#     'adjclose': 112197.0,
#     'formatted_date': '2020-03-16'},
#    {'date': 1584428400,
#     'high': 118769.0,
#     'low': 108751.0,
#     'open': 113500.0,
#     'close': 110990.0,
#     'volume': 434208,
#     'adjclose': 110990.0,
#     'formatted_date': '2020-03-17'},
#    {'date': 1584514800,
#     'high': 109874.0,
#     'low': 80000.0,
#     'open': 107999.0,
#     'close': 80000.0,
#     'volume': 1194496,
#     'adjclose': 80000.0,
#     'formatted_date': '2020-03-18'},
#    {'date': 1584601200,
#     'high': 81000.0,
#     'low': 53986.0,
#     'open': 80000.0,
#     'close': 68250.0,
#     'volume': 3377072,
# ...
